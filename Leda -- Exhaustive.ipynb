# %%
import json
import collections
import subprocess

def prettify(atom):

    s = atom['predicate']
    if 'terms' in atom:
        s += '('
        ts = [prettify(t) for t in atom['terms']]
        s += ','.join(ts)
        s += ')'
    return s

  
def parse_json_result(out):
    """Parse the provided JSON text and extract a dict
    representing the predicates described in the first solver result."""
    result = json.loads(out)
    assert len(result['Call']) > 0
    if 'Witnesses' not in result['Call'][0]:
        return []
    
    if len(result['Call'][0]['Witnesses']) == 0:
        return []
    
    all_preds = []
    ids = range(len(result['Call'][0]['Witnesses']))
    
    witness = result['Call'][0]['Witnesses'][0]['Value']

    class identitydefaultdict(collections.defaultdict):
        def __missing__(self, key):
            return key

    preds = collections.defaultdict(list)
    env = identitydefaultdict()

    for atom in witness:
        parsed,dummy = parse_terms(atom)
        preds[parsed[0]['predicate']].append(parsed)
    return preds

def solve(args):
    """Run clingo with the provided argument list and return the parsed JSON result."""

    args = ['clingo','--outf=2'] + args
    clingo = subprocess.Popen(
        ' '.join(args),
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        shell=True
        )
    out, err = clingo.communicate()
            
    return parse_json_result(out)

def parse_terms(arguments):
    terms = []
    while len(arguments) > 0:
        l_paren = arguments.find('(')
        r_paren = arguments.find(')')
        comma = arguments.find(',')
        if l_paren < 0:
            l_paren = len(arguments)-1
        if r_paren < 0:
            r_paren = len(arguments)-1
        if comma < 0:
            comma = len(arguments)-1
        next = min(l_paren,r_paren,comma)
        next_c = arguments[next]
        if next_c == '(':
        
            pred = arguments[:next]
            sub_terms, arguments = parse_terms(arguments[next+1:]) 
            terms.append({'predicate':pred,'terms':sub_terms})
        elif next_c == ')':
            pred = arguments[:next]
            if pred != '':
                terms.append({'predicate':arguments[:next]})
            arguments = arguments[next+1:]
            return terms,arguments
        elif next_c == ',':
            pred = arguments[:next]
            if pred != '':
                terms.append({'predicate':arguments[:next]})
            arguments = arguments[next+1:]
        else:
            terms.append({'predicate':arguments})
            arguments = ''
    return terms, ''

# %%
filenames = ['pong.lp','kaboom.lp']

games = []
types = {}
facts = []
for filename in filenames:
    rules = open(filename,'rb').read().replace(' ','').replace('\n','').split('.')[:-1]
    rules = [parse_terms(rule)[0][0] for rule in rules]
    per_game_facts = []
    for rule in rules:
        if rule['predicate'] == 'type':
            types[rule['terms'][1]['predicate']] = rule['terms'][0]['predicate']
        else: 
            facts.append(rule)
            per_game_facts.append(rule)
    games.append([prettify(rule) for rule in per_game_facts])

# %%
def has_term(rule,term):
    
    if 'terms' in rule:
        
        for rule_term in rule['terms']:
                if has_term(rule_term,term):
                    return True
        return False
    elif rule['predicate'] == term:
        return True
    else:
        return False
def get_terms(rule):
    if 'terms' in rule:
        terms = []
        for rule_term in rule['terms']:
            terms += get_terms(rule_term)
        return terms
    else:
        return [rule['predicate']]
def get_higher_level(rule):
    if 'terms' in rule:
        
        terms = [prettify(rule)]
        for rule_term in rule['terms']:
            terms += get_higher_level(rule_term)
        return terms
    else:
        return []

# %%
import random
import sys
import numpy as np
import hashlib
import os


max_rules = 2
temperature = 5

# %%
def replace(fact,source,target):
    if 'terms' in fact:
        terms = []
        for fact_term in fact['terms']:
            terms.append(replace(fact_term,source,target))
        return {'predicate':fact['predicate'],
                'terms':terms}
    else:
        pred = fact['predicate']
        if pred == source:
            pred = target
        return {'predicate':pred}
    
def create_rule_graph(game,positives):
    terms_to_fact = {}
    
    all_terms = {}
    all_rules = {}
    for positive_id,positive in enumerate(positives):
        terms = get_terms(positive)
        terms_to_fact = {term:[-positive_id-1]  for term in terms}
        all_terms[-positive_id-1] = terms
        all_rules[-positive_id-1] = positive
        
    
    for rule_id,rule in enumerate(game):
        terms = get_terms(rule)
        all_terms[rule_id] = terms
        for term in terms:
            if term not in terms_to_fact:
                terms_to_fact[term] = []
            terms_to_fact[term].append(rule_id)
        all_rules[rule_id] = rule
    print terms_to_fact['paddle_player']
    visited = set()
    connections = {}
    
    stack = list(sorted([i for i in all_terms if i < 0]))
    print stack
    while len(stack) > 0:        
        print 'stack', stack
        current = stack.pop(0)
        visited.add(current)
        if current not in connections:
            connections[current] = set()
        for term in all_terms[current]:
            for connection in terms_to_fact[term]:
                if connection not in visited and connection not in stack:
                    if connection not in connections:
                        connections[connection] = set()
                    connections[connection].add(current)
                    connections[current].add(connection)
                        
                    stack.append(connection)
                elif connection != current:
                    connections[connection].add(current)
                    connections[current].add(connection)
        
    return connections,all_rules

# %%
target_rule  = {'predicate':'player_controls','terms':[{'predicate':'entity'}]}


all_positives = []
all_raw_positives = []

positives = [{'predicate':'player_controls','terms':[{'predicate':'paddle_player'}]}]
all_raw_positives.append(positives[-1])
positives = [prettify(f) for f in positives]
all_positives.append(positives)


positives = [{'predicate':'player_controls','terms':[{'predicate':'basket'}]}]
all_raw_positives.append(positives[-1])
positives = [prettify(f) for f in positives]
all_positives.append(positives)

connections,rules = create_rule_graph(facts,all_raw_positives)

for c in sorted(connections):
    print prettify(rules[c])
    for cc in connections[c]:
        print '\t->', prettify(rules[cc])
# Out:
# [1, 4, 18, 20, 30]
# [-2, -1]
# stack [-2, -1]
# stack [-1, 40, 43, 65, 69, 71]
# stack [40, 43, 65, 69, 71, 1, 4, 18, 20, 30]
# stack [43, 65, 69, 71, 1, 4, 18, 20, 30]
# stack [65, 69, 71, 1, 4, 18, 20, 30]
# stack [69, 71, 1, 4, 18, 20, 30, 41, 44, 60, 64, 66, 72, 67]
# stack [71, 1, 4, 18, 20, 30, 41, 44, 60, 64, 66, 72, 67, 68, 56, 22, 24, 27, 34, 61, 73]
# stack [1, 4, 18, 20, 30, 41, 44, 60, 64, 66, 72, 67, 68, 56, 22, 24, 27, 34, 61, 73, 70]
# stack [4, 18, 20, 30, 41, 44, 60, 64, 66, 72, 67, 68, 56, 22, 24, 27, 34, 61, 73, 70]
# stack [18, 20, 30, 41, 44, 60, 64, 66, 72, 67, 68, 56, 22, 24, 27, 34, 61, 73, 70]
# stack [20, 30, 41, 44, 60, 64, 66, 72, 67, 68, 56, 22, 24, 27, 34, 61, 73, 70, 17]
# stack [30, 41, 44, 60, 64, 66, 72, 67, 68, 56, 22, 24, 27, 34, 61, 73, 70, 17, 19]
# stack [41, 44, 60, 64, 66, 72, 67, 68, 56, 22, 24, 27, 34, 61, 73, 70, 17, 19, 0, 3, 13, 16, 21, 23, 25, 28, 29, 31, 32]
# stack [44, 60, 64, 66, 72, 67, 68, 56, 22, 24, 27, 34, 61, 73, 70, 17, 19, 0, 3, 13, 16, 21, 23, 25, 28, 29, 31, 32]
# stack [60, 64, 66, 72, 67, 68, 56, 22, 24, 27, 34, 61, 73, 70, 17, 19, 0, 3, 13, 16, 21, 23, 25, 28, 29, 31, 32]
# stack [64, 66, 72, 67, 68, 56, 22, 24, 27, 34, 61, 73, 70, 17, 19, 0, 3, 13, 16, 21, 23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63]
# stack [66, 72, 67, 68, 56, 22, 24, 27, 34, 61, 73, 70, 17, 19, 0, 3, 13, 16, 21, 23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62]
# stack [72, 67, 68, 56, 22, 24, 27, 34, 61, 73, 70, 17, 19, 0, 3, 13, 16, 21, 23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62]
# stack [67, 68, 56, 22, 24, 27, 34, 61, 73, 70, 17, 19, 0, 3, 13, 16, 21, 23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74]
# stack [68, 56, 22, 24, 27, 34, 61, 73, 70, 17, 19, 0, 3, 13, 16, 21, 23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74]
# stack [56, 22, 24, 27, 34, 61, 73, 70, 17, 19, 0, 3, 13, 16, 21, 23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74]
# stack [22, 24, 27, 34, 61, 73, 70, 17, 19, 0, 3, 13, 16, 21, 23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74]
# stack [24, 27, 34, 61, 73, 70, 17, 19, 0, 3, 13, 16, 21, 23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5]
# stack [27, 34, 61, 73, 70, 17, 19, 0, 3, 13, 16, 21, 23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5]
# stack [34, 61, 73, 70, 17, 19, 0, 3, 13, 16, 21, 23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37]
# stack [61, 73, 70, 17, 19, 0, 3, 13, 16, 21, 23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35]
# stack [73, 70, 17, 19, 0, 3, 13, 16, 21, 23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47]
# stack [70, 17, 19, 0, 3, 13, 16, 21, 23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75]
# stack [17, 19, 0, 3, 13, 16, 21, 23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75]
# stack [19, 0, 3, 13, 16, 21, 23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75]
# stack [0, 3, 13, 16, 21, 23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75]
# stack [3, 13, 16, 21, 23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75]
# stack [13, 16, 21, 23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75]
# stack [16, 21, 23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12]
# stack [21, 23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15]
# stack [23, 25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15]
# stack [25, 28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15]
# stack [28, 29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15]
# stack [29, 31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15]
# stack [31, 32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15]
# stack [32, 39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15]
# stack [39, 42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15]
# stack [42, 49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15]
# stack [49, 50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15]
# stack [50, 51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15]
# stack [51, 53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15]
# stack [53, 54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15]
# stack [54, 55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15]
# stack [55, 57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15, 52]
# stack [57, 58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15, 52]
# stack [58, 59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15, 52]
# stack [59, 63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15, 52]
# stack [63, 62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15, 52]
# stack [62, 74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15, 52]
# stack [74, 2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15, 52]
# stack [2, 5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15, 52]
# stack [5, 26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15, 52]
# stack [26, 7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15, 52]
# stack [7, 37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15, 52, 8]
# stack [37, 33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15, 52, 8]
# stack [33, 6, 35, 47, 48, 75, 10, 11, 12, 14, 15, 52, 8, 38, 76]
# stack [6, 35, 47, 48, 75, 10, 11, 12, 14, 15, 52, 8, 38, 76]
# stack [35, 47, 48, 75, 10, 11, 12, 14, 15, 52, 8, 38, 76]
# stack [47, 48, 75, 10, 11, 12, 14, 15, 52, 8, 38, 76, 36]
# stack [48, 75, 10, 11, 12, 14, 15, 52, 8, 38, 76, 36]
# stack [75, 10, 11, 12, 14, 15, 52, 8, 38, 76, 36]
# stack [10, 11, 12, 14, 15, 52, 8, 38, 76, 36]
# stack [11, 12, 14, 15, 52, 8, 38, 76, 36]
# stack [12, 14, 15, 52, 8, 38, 76, 36]
# stack [14, 15, 52, 8, 38, 76, 36]
# stack [15, 52, 8, 38, 76, 36, 9]
# stack [52, 8, 38, 76, 36, 9]
# stack [8, 38, 76, 36, 9]
# stack [38, 76, 36, 9]
# stack [76, 36, 9]
# stack [36, 9]
# stack [9]
# player_controls(basket)
# 	-> entity(basket)
# 	-> precondition(overlaps(bomb,basket),defuse)
# 	-> singular(basket)
# 	-> result(move_right,moves(basket,east,low))
# 	-> result(move_left,moves(basket,west,low))
# player_controls(paddle_player)
# 	-> entity(paddle_player)
# 	-> result(move_up,moves(paddle_player,north,low))
# 	-> singular(paddle_player)
# 	-> precondition(overlaps(ball,paddle_player),player_hit)
# 	-> result(move_down,moves(paddle_player,south,low))
# entity(ball)
# 	-> precondition(overlaps(ball,screen_right),player_score)
# 	-> singular(ball)
# 	-> result(player_serve,apply_impulse(ball,vector(north_east)))
# 	-> result(computer_serve,apply_impulse(ball,vector(north_west)))
# 	-> precondition(above(paddle_computer,ball),move_up_computer)
# 	-> precondition(below(paddle_computer,ball),move_down_computer)
# 	-> precondition(overlaps(ball,screen_left),computer_score)
# 	-> precondition(overlaps(ball,paddle_computer),computer_hit)
# 	-> result(computer_hit,reflect_velocity(ball,collision_normal(ball,paddle_computer)))
# 	-> precondition(overlaps(ball,paddle_player),player_hit)
# 	-> result(player_hit,reflect_velocity(ball,collision_normal(ball,player_hit)))
# entity(paddle_player)
# 	-> result(move_down,moves(paddle_player,south,low))
# 	-> result(move_up,moves(paddle_player,north,low))
# 	-> singular(paddle_player)
# 	-> precondition(overlaps(ball,paddle_player),player_hit)
# 	-> player_controls(paddle_player)
# entity(paddle_computer)
# 	-> singular(paddle_computer)
# 	-> precondition(above(paddle_computer,ball),move_up_computer)
# 	-> result(move_up_computer,moves(paddle_computer,north,low))
# 	-> precondition(below(paddle_computer,ball),move_down_computer)
# 	-> result(move_down_computer,moves(paddle_computer,south,low))
# 	-> precondition(overlaps(ball,paddle_computer),computer_hit)
# 	-> result(computer_hit,reflect_velocity(ball,collision_normal(ball,paddle_computer)))
# singular(ball)
# 	-> entity(ball)
# 	-> precondition(overlaps(ball,screen_right),player_score)
# 	-> result(player_serve,apply_impulse(ball,vector(north_east)))
# 	-> result(computer_serve,apply_impulse(ball,vector(north_west)))
# 	-> precondition(above(paddle_computer,ball),move_up_computer)
# 	-> precondition(below(paddle_computer,ball),move_down_computer)
# 	-> precondition(overlaps(ball,screen_left),computer_score)
# 	-> precondition(overlaps(ball,paddle_computer),computer_hit)
# 	-> result(computer_hit,reflect_velocity(ball,collision_normal(ball,paddle_computer)))
# 	-> precondition(overlaps(ball,paddle_player),player_hit)
# 	-> result(player_hit,reflect_velocity(ball,collision_normal(ball,player_hit)))
# singular(paddle_player)
# 	-> entity(paddle_player)
# 	-> result(move_up,moves(paddle_player,north,low))
# 	-> result(move_down,moves(paddle_player,south,low))
# 	-> precondition(overlaps(ball,paddle_player),player_hit)
# 	-> player_controls(paddle_player)
# singular(paddle_computer)
# 	-> entity(paddle_computer)
# 	-> precondition(above(paddle_computer,ball),move_up_computer)
# 	-> result(move_up_computer,moves(paddle_computer,north,low))
# 	-> precondition(below(paddle_computer,ball),move_down_computer)
# 	-> result(move_down_computer,moves(paddle_computer,south,low))
# 	-> precondition(overlaps(ball,paddle_computer),computer_hit)
# 	-> result(computer_hit,reflect_velocity(ball,collision_normal(ball,paddle_computer)))
# resource(score_player)
# 	-> result(player_score,increase(score_player,low))
# 	-> precondition(ge(score_player,high),win)
# resource(score_computer)
# 	-> result(computer_score,increase(score_computer,low))
# 	-> precondition(ge(score_computer,high),lose)
# resource(player_start)
# 	-> result(player_score,set(player_start,true))
# 	-> result(computer_score,set(player_start,true))
# 	-> result(player_serve,set(player_start,false))
# 	-> precondition(eq(player_start,true),player_serve)
# resource(computer_start)
# 	-> precondition(eq(computer_start,true),computer_serve)
# 	-> result(computer_serve,set(computer_start,false))
# precondition(eq(player_start,true),player_serve)
# 	-> result(player_score,set(player_start,true))
# 	-> resource(player_start)
# 	-> result(lose_life,set(paused,true))
# 	-> precondition(control_event(player_input(space,pressed)),player_serve)
# 	-> result(player_serve,set(player_start,false))
# 	-> result(player_serve,apply_impulse(ball,vector(north_east)))
# 	-> precondition(eq(computer_start,true),computer_serve)
# 	-> result(computer_score,set(player_start,true))
# precondition(control_event(player_input(space,pressed)),player_serve)
# 	-> precondition(eq(player_start,true),player_serve)
# 	-> result(player_serve,set(player_start,false))
# 	-> result(player_serve,apply_impulse(ball,vector(north_east)))
# result(player_serve,set(player_start,false))
# 	-> result(player_score,set(player_start,true))
# 	-> resource(player_start)
# 	-> precondition(eq(player_start,true),player_serve)
# 	-> precondition(control_event(player_input(space,pressed)),player_serve)
# 	-> result(player_serve,apply_impulse(ball,vector(north_east)))
# 	-> result(computer_serve,set(computer_start,false))
# 	-> precondition(eq(paused,false),change_direction(bomber))
# 	-> result(computer_score,set(player_start,true))
# 	-> precondition(eq(paused,false),throw_bomb(bomber))
# 	-> precondition(eq(paused,false),tick)
# result(player_serve,apply_impulse(ball,vector(north_east)))
# 	-> entity(ball)
# 	-> precondition(overlaps(ball,screen_right),player_score)
# 	-> singular(ball)
# 	-> precondition(eq(player_start,true),player_serve)
# 	-> precondition(control_event(player_input(space,pressed)),player_serve)
# 	-> result(player_serve,set(player_start,false))
# 	-> result(computer_serve,apply_impulse(ball,vector(north_west)))
# 	-> precondition(above(paddle_computer,ball),move_up_computer)
# 	-> precondition(below(paddle_computer,ball),move_down_computer)
# 	-> precondition(overlaps(ball,screen_left),computer_score)
# 	-> precondition(overlaps(ball,paddle_computer),computer_hit)
# 	-> result(computer_hit,reflect_velocity(ball,collision_normal(ball,paddle_computer)))
# 	-> precondition(overlaps(ball,paddle_player),player_hit)
# 	-> result(player_hit,reflect_velocity(ball,collision_normal(ball,player_hit)))
# precondition(eq(computer_start,true),computer_serve)
# 	-> result(player_score,set(player_start,true))
# 	-> resource(computer_start)
# 	-> result(lose_life,set(paused,true))
# 	-> result(computer_serve,set(computer_start,false))
# 	-> result(computer_serve,apply_impulse(ball,vector(north_west)))
# 	-> result(computer_score,set(player_start,true))
# 	-> precondition(eq(player_start,true),player_serve)
# result(computer_serve,set(computer_start,false))
# 	-> resource(computer_start)
# 	-> result(player_serve,set(player_start,false))
# 	-> precondition(eq(computer_start,true),computer_serve)
# 	-> result(computer_serve,apply_impulse(ball,vector(north_west)))
# 	-> precondition(eq(paused,false),change_direction(bomber))
# 	-> precondition(eq(paused,false),throw_bomb(bomber))
# 	-> precondition(eq(paused,false),tick)
# result(computer_serve,apply_impulse(ball,vector(north_west)))
# 	-> entity(ball)
# 	-> precondition(overlaps(ball,screen_right),player_score)
# 	-> singular(ball)
# 	-> result(player_serve,apply_impulse(ball,vector(north_east)))
# 	-> precondition(eq(computer_start,true),computer_serve)
# 	-> result(computer_serve,set(computer_start,false))
# 	-> precondition(above(paddle_computer,ball),move_up_computer)
# 	-> precondition(below(paddle_computer,ball),move_down_computer)
# 	-> precondition(overlaps(ball,screen_left),computer_score)
# 	-> precondition(overlaps(ball,paddle_computer),computer_hit)
# 	-> result(computer_hit,reflect_velocity(ball,collision_normal(ball,paddle_computer)))
# 	-> precondition(overlaps(ball,paddle_player),player_hit)
# 	-> result(player_hit,reflect_velocity(ball,collision_normal(ball,player_hit)))
# precondition(control_event(player_input(up_arrow,held)),move_up)
# 	-> result(move_up,moves(paddle_player,north,low))
# 	-> precondition(control_event(player_input(down_arrow,held)),move_down)
# 	-> precondition(control_event(player_input(right_arrow,held)),move_right)
# 	-> precondition(control_event(player_input(left_arrow,held)),move_left)
# result(move_up,moves(paddle_player,north,low))
# 	-> entity(paddle_player)
# 	-> result(player_score,increase(score_player,low))
# 	-> result(defuse,increase(score,low))
# 	-> singular(paddle_player)
# 	-> result(move_right,moves(basket,east,low))
# 	-> result(move_left,moves(basket,west,low))
# 	-> result(lose_life,decrease(lives,low))
# 	-> precondition(control_event(player_input(up_arrow,held)),move_up)
# 	-> result(move_down,moves(paddle_player,south,low))
# 	-> precondition(overlaps(ball,paddle_player),player_hit)
# 	-> result(move_up_computer,moves(paddle_computer,north,low))
# 	-> result(move_down_computer,moves(paddle_computer,south,low))
# 	-> result(computer_score,increase(score_computer,low))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> player_controls(paddle_player)
# precondition(control_event(player_input(down_arrow,held)),move_down)
# 	-> precondition(control_event(player_input(right_arrow,held)),move_right)
# 	-> result(move_down,moves(paddle_player,south,low))
# 	-> precondition(control_event(player_input(left_arrow,held)),move_left)
# 	-> precondition(control_event(player_input(up_arrow,held)),move_up)
# result(move_down,moves(paddle_player,south,low))
# 	-> result(tick,moves(bomb,south))
# 	-> entity(paddle_player)
# 	-> result(player_score,increase(score_player,low))
# 	-> result(defuse,increase(score,low))
# 	-> singular(paddle_player)
# 	-> result(move_right,moves(basket,east,low))
# 	-> result(move_left,moves(basket,west,low))
# 	-> result(lose_life,decrease(lives,low))
# 	-> result(move_up,moves(paddle_player,north,low))
# 	-> precondition(control_event(player_input(down_arrow,held)),move_down)
# 	-> precondition(overlaps(ball,paddle_player),player_hit)
# 	-> result(move_up_computer,moves(paddle_computer,north,low))
# 	-> result(move_down_computer,moves(paddle_computer,south,low))
# 	-> result(computer_score,increase(score_computer,low))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> player_controls(paddle_player)
# precondition(above(paddle_computer,ball),move_up_computer)
# 	-> entity(ball)
# 	-> precondition(overlaps(ball,screen_right),player_score)
# 	-> entity(paddle_computer)
# 	-> singular(ball)
# 	-> singular(paddle_computer)
# 	-> result(player_serve,apply_impulse(ball,vector(north_east)))
# 	-> result(computer_serve,apply_impulse(ball,vector(north_west)))
# 	-> result(move_up_computer,moves(paddle_computer,north,low))
# 	-> precondition(below(paddle_computer,ball),move_down_computer)
# 	-> result(move_down_computer,moves(paddle_computer,south,low))
# 	-> precondition(overlaps(ball,screen_left),computer_score)
# 	-> precondition(overlaps(ball,paddle_computer),computer_hit)
# 	-> result(computer_hit,reflect_velocity(ball,collision_normal(ball,paddle_computer)))
# 	-> precondition(overlaps(ball,paddle_player),player_hit)
# 	-> result(player_hit,reflect_velocity(ball,collision_normal(ball,player_hit)))
# result(move_up_computer,moves(paddle_computer,north,low))
# 	-> entity(paddle_computer)
# 	-> result(defuse,increase(score,low))
# 	-> result(move_right,moves(basket,east,low))
# 	-> result(move_left,moves(basket,west,low))
# 	-> result(lose_life,decrease(lives,low))
# 	-> result(player_score,increase(score_player,low))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> result(move_up,moves(paddle_player,north,low))
# 	-> result(move_down,moves(paddle_player,south,low))
# 	-> precondition(above(paddle_computer,ball),move_up_computer)
# 	-> precondition(below(paddle_computer,ball),move_down_computer)
# 	-> result(move_down_computer,moves(paddle_computer,south,low))
# 	-> result(computer_score,increase(score_computer,low))
# 	-> precondition(overlaps(ball,paddle_computer),computer_hit)
# 	-> result(computer_hit,reflect_velocity(ball,collision_normal(ball,paddle_computer)))
# 	-> singular(paddle_computer)
# precondition(below(paddle_computer,ball),move_down_computer)
# 	-> entity(ball)
# 	-> precondition(overlaps(ball,screen_right),player_score)
# 	-> entity(paddle_computer)
# 	-> singular(ball)
# 	-> singular(paddle_computer)
# 	-> result(player_serve,apply_impulse(ball,vector(north_east)))
# 	-> result(computer_serve,apply_impulse(ball,vector(north_west)))
# 	-> precondition(above(paddle_computer,ball),move_up_computer)
# 	-> result(move_up_computer,moves(paddle_computer,north,low))
# 	-> result(move_down_computer,moves(paddle_computer,south,low))
# 	-> precondition(overlaps(ball,screen_left),computer_score)
# 	-> precondition(overlaps(ball,paddle_computer),computer_hit)
# 	-> result(computer_hit,reflect_velocity(ball,collision_normal(ball,paddle_computer)))
# 	-> precondition(overlaps(ball,paddle_player),player_hit)
# 	-> result(player_hit,reflect_velocity(ball,collision_normal(ball,player_hit)))
# result(move_down_computer,moves(paddle_computer,south,low))
# 	-> result(tick,moves(bomb,south))
# 	-> entity(paddle_computer)
# 	-> result(defuse,increase(score,low))
# 	-> result(move_right,moves(basket,east,low))
# 	-> result(move_left,moves(basket,west,low))
# 	-> result(lose_life,decrease(lives,low))
# 	-> result(player_score,increase(score_player,low))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> result(move_up,moves(paddle_player,north,low))
# 	-> result(move_down,moves(paddle_player,south,low))
# 	-> precondition(above(paddle_computer,ball),move_up_computer)
# 	-> result(move_up_computer,moves(paddle_computer,north,low))
# 	-> precondition(below(paddle_computer,ball),move_down_computer)
# 	-> result(computer_score,increase(score_computer,low))
# 	-> precondition(overlaps(ball,paddle_computer),computer_hit)
# 	-> result(computer_hit,reflect_velocity(ball,collision_normal(ball,paddle_computer)))
# 	-> singular(paddle_computer)
# precondition(overlaps(ball,screen_left),computer_score)
# 	-> entity(ball)
# 	-> precondition(overlaps(ball,screen_right),player_score)
# 	-> singular(ball)
# 	-> result(player_serve,apply_impulse(ball,vector(north_east)))
# 	-> result(computer_serve,apply_impulse(ball,vector(north_west)))
# 	-> precondition(above(paddle_computer,ball),move_up_computer)
# 	-> precondition(below(paddle_computer,ball),move_down_computer)
# 	-> result(computer_score,set(player_start,true))
# 	-> result(computer_score,increase(score_computer,low))
# 	-> precondition(overlaps(ball,paddle_computer),computer_hit)
# 	-> result(computer_hit,reflect_velocity(ball,collision_normal(ball,paddle_computer)))
# 	-> precondition(overlaps(ball,paddle_player),player_hit)
# 	-> result(player_hit,reflect_velocity(ball,collision_normal(ball,player_hit)))
# result(computer_score,set(player_start,true))
# 	-> result(player_score,set(player_start,true))
# 	-> resource(player_start)
# 	-> result(lose_life,set(paused,true))
# 	-> result(player_serve,set(player_start,false))
# 	-> precondition(eq(computer_start,true),computer_serve)
# 	-> precondition(overlaps(ball,screen_left),computer_score)
# 	-> result(computer_score,increase(score_computer,low))
# 	-> precondition(eq(player_start,true),player_serve)
# result(computer_score,increase(score_computer,low))
# 	-> result(player_score,increase(score_player,low))
# 	-> result(defuse,increase(score,low))
# 	-> result(move_right,moves(basket,east,low))
# 	-> result(move_left,moves(basket,west,low))
# 	-> result(lose_life,decrease(lives,low))
# 	-> resource(score_computer)
# 	-> result(move_up,moves(paddle_player,north,low))
# 	-> result(move_down,moves(paddle_player,south,low))
# 	-> result(move_up_computer,moves(paddle_computer,north,low))
# 	-> result(move_down_computer,moves(paddle_computer,south,low))
# 	-> precondition(overlaps(ball,screen_left),computer_score)
# 	-> result(computer_score,set(player_start,true))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> precondition(ge(score_computer,high),lose)
# precondition(overlaps(ball,paddle_computer),computer_hit)
# 	-> entity(ball)
# 	-> precondition(overlaps(ball,screen_right),player_score)
# 	-> entity(paddle_computer)
# 	-> singular(ball)
# 	-> singular(paddle_computer)
# 	-> result(player_serve,apply_impulse(ball,vector(north_east)))
# 	-> result(computer_serve,apply_impulse(ball,vector(north_west)))
# 	-> precondition(above(paddle_computer,ball),move_up_computer)
# 	-> result(move_up_computer,moves(paddle_computer,north,low))
# 	-> precondition(below(paddle_computer,ball),move_down_computer)
# 	-> result(move_down_computer,moves(paddle_computer,south,low))
# 	-> precondition(overlaps(ball,screen_left),computer_score)
# 	-> result(computer_hit,reflect_velocity(ball,collision_normal(ball,paddle_computer)))
# 	-> precondition(overlaps(ball,paddle_player),player_hit)
# 	-> result(player_hit,reflect_velocity(ball,collision_normal(ball,player_hit)))
# result(computer_hit,reflect_velocity(ball,collision_normal(ball,paddle_computer)))
# 	-> entity(ball)
# 	-> precondition(overlaps(ball,screen_right),player_score)
# 	-> entity(paddle_computer)
# 	-> singular(ball)
# 	-> singular(paddle_computer)
# 	-> result(player_serve,apply_impulse(ball,vector(north_east)))
# 	-> result(computer_serve,apply_impulse(ball,vector(north_west)))
# 	-> precondition(above(paddle_computer,ball),move_up_computer)
# 	-> result(move_up_computer,moves(paddle_computer,north,low))
# 	-> precondition(below(paddle_computer,ball),move_down_computer)
# 	-> result(move_down_computer,moves(paddle_computer,south,low))
# 	-> precondition(overlaps(ball,screen_left),computer_score)
# 	-> precondition(overlaps(ball,paddle_computer),computer_hit)
# 	-> precondition(overlaps(ball,paddle_player),player_hit)
# 	-> result(player_hit,reflect_velocity(ball,collision_normal(ball,player_hit)))
# precondition(overlaps(ball,paddle_player),player_hit)
# 	-> entity(ball)
# 	-> entity(paddle_player)
# 	-> singular(ball)
# 	-> singular(paddle_player)
# 	-> precondition(overlaps(ball,screen_right),player_score)
# 	-> result(player_serve,apply_impulse(ball,vector(north_east)))
# 	-> result(computer_serve,apply_impulse(ball,vector(north_west)))
# 	-> result(move_up,moves(paddle_player,north,low))
# 	-> result(move_down,moves(paddle_player,south,low))
# 	-> precondition(above(paddle_computer,ball),move_up_computer)
# 	-> precondition(below(paddle_computer,ball),move_down_computer)
# 	-> precondition(overlaps(ball,screen_left),computer_score)
# 	-> precondition(overlaps(ball,paddle_computer),computer_hit)
# 	-> result(computer_hit,reflect_velocity(ball,collision_normal(ball,paddle_computer)))
# 	-> player_controls(paddle_player)
# 	-> result(player_hit,reflect_velocity(ball,collision_normal(ball,player_hit)))
# result(player_hit,reflect_velocity(ball,collision_normal(ball,player_hit)))
# 	-> entity(ball)
# 	-> precondition(overlaps(ball,screen_right),player_score)
# 	-> singular(ball)
# 	-> result(player_serve,apply_impulse(ball,vector(north_east)))
# 	-> result(computer_serve,apply_impulse(ball,vector(north_west)))
# 	-> precondition(above(paddle_computer,ball),move_up_computer)
# 	-> precondition(below(paddle_computer,ball),move_down_computer)
# 	-> precondition(overlaps(ball,screen_left),computer_score)
# 	-> precondition(overlaps(ball,paddle_computer),computer_hit)
# 	-> result(computer_hit,reflect_velocity(ball,collision_normal(ball,paddle_computer)))
# 	-> precondition(overlaps(ball,paddle_player),player_hit)
# precondition(overlaps(ball,screen_right),player_score)
# 	-> entity(ball)
# 	-> result(player_score,set(player_start,true))
# 	-> result(player_score,increase(score_player,low))
# 	-> singular(ball)
# 	-> result(player_serve,apply_impulse(ball,vector(north_east)))
# 	-> result(computer_serve,apply_impulse(ball,vector(north_west)))
# 	-> precondition(above(paddle_computer,ball),move_up_computer)
# 	-> precondition(below(paddle_computer,ball),move_down_computer)
# 	-> precondition(overlaps(ball,screen_left),computer_score)
# 	-> precondition(overlaps(ball,paddle_computer),computer_hit)
# 	-> result(computer_hit,reflect_velocity(ball,collision_normal(ball,paddle_computer)))
# 	-> precondition(overlaps(ball,paddle_player),player_hit)
# 	-> result(player_hit,reflect_velocity(ball,collision_normal(ball,player_hit)))
# result(player_score,set(player_start,true))
# 	-> precondition(overlaps(ball,screen_right),player_score)
# 	-> result(player_score,increase(score_player,low))
# 	-> resource(player_start)
# 	-> result(lose_life,set(paused,true))
# 	-> result(player_serve,set(player_start,false))
# 	-> precondition(eq(computer_start,true),computer_serve)
# 	-> result(computer_score,set(player_start,true))
# 	-> precondition(eq(player_start,true),player_serve)
# result(player_score,increase(score_player,low))
# 	-> precondition(overlaps(ball,screen_right),player_score)
# 	-> result(player_score,set(player_start,true))
# 	-> result(defuse,increase(score,low))
# 	-> result(move_right,moves(basket,east,low))
# 	-> resource(score_player)
# 	-> result(move_left,moves(basket,west,low))
# 	-> result(lose_life,decrease(lives,low))
# 	-> result(move_up,moves(paddle_player,north,low))
# 	-> precondition(ge(score_player,high),win)
# 	-> result(move_down,moves(paddle_player,south,low))
# 	-> result(move_up_computer,moves(paddle_computer,north,low))
# 	-> result(move_down_computer,moves(paddle_computer,south,low))
# 	-> result(computer_score,increase(score_computer,low))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# precondition(ge(score_player,high),win)
# 	-> result(player_score,increase(score_player,low))
# 	-> result(win,mode_change(game_win))
# 	-> precondition(ge(score_computer,high),lose)
# 	-> resource(score_player)
# result(win,mode_change(game_win))
# 	-> precondition(ge(score_player,high),win)
# precondition(ge(score_computer,high),lose)
# 	-> precondition(ge(score_player,high),win)
# 	-> result(lose,mode_change(game_loss))
# 	-> resource(score_computer)
# 	-> precondition(le(lives,0),lose)
# 	-> result(lose,mode_change(game_loss))
# 	-> result(computer_score,increase(score_computer,low))
# result(lose,mode_change(game_loss))
# 	-> precondition(le(lives,0),lose)
# 	-> result(lose,mode_change(game_loss))
# 	-> precondition(ge(score_computer,high),lose)
# entity(bomber)
# 	-> singular(bomber)
# 	-> resource(bomber,duration)
# 	-> resource(bomber,direction)
# 	-> resource(bomber,timetilnextbomb)
# 	-> timerlogic(bomber,change_direction,duration,loop)
# 	-> precondition(eq(paused,false),change_direction(bomber))
# 	-> precondition(timer_elapsed(bomber,change_direction),change_direction(bomber))
# 	-> result(change_direction(bomber),set(direction,random_choice(east,west)))
# 	-> timerlogic(bomber,throw_bomb,timetilnextbomb,loop)
# 	-> precondition(eq(paused,false),throw_bomb(bomber))
# 	-> precondition(timer_elapsed(bomber,throw_bomb),throw_bomb(bomber))
# 	-> result(throw_bomb(bomber),add(bomb))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> result(tick,moves(bomber,direction))
# entity(basket)
# 	-> precondition(overlaps(bomb,basket),defuse)
# 	-> singular(basket)
# 	-> result(move_right,moves(basket,east,low))
# 	-> player_controls(basket)
# 	-> result(move_left,moves(basket,west,low))
# entity(bomb)
# 	-> result(tick,moves(bomb,south))
# 	-> precondition(overlaps(bomb,basket),defuse)
# 	-> result(defuse,delete(bomb))
# 	-> precondition(overlaps(bomb,screen_bottom),lose_life)
# 	-> many(bomb)
# 	-> result(throw_bomb(bomber),add(bomb))
# singular(bomber)
# 	-> entity(bomber)
# 	-> resource(bomber,duration)
# 	-> resource(bomber,direction)
# 	-> resource(bomber,timetilnextbomb)
# 	-> timerlogic(bomber,change_direction,duration,loop)
# 	-> precondition(eq(paused,false),change_direction(bomber))
# 	-> precondition(timer_elapsed(bomber,change_direction),change_direction(bomber))
# 	-> result(change_direction(bomber),set(direction,random_choice(east,west)))
# 	-> timerlogic(bomber,throw_bomb,timetilnextbomb,loop)
# 	-> precondition(eq(paused,false),throw_bomb(bomber))
# 	-> precondition(timer_elapsed(bomber,throw_bomb),throw_bomb(bomber))
# 	-> result(throw_bomb(bomber),add(bomb))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> result(tick,moves(bomber,direction))
# singular(basket)
# 	-> entity(basket)
# 	-> precondition(overlaps(bomb,basket),defuse)
# 	-> result(move_right,moves(basket,east,low))
# 	-> player_controls(basket)
# 	-> result(move_left,moves(basket,west,low))
# many(bomb)
# 	-> result(tick,moves(bomb,south))
# 	-> precondition(overlaps(bomb,basket),defuse)
# 	-> result(defuse,delete(bomb))
# 	-> precondition(overlaps(bomb,screen_bottom),lose_life)
# 	-> entity(bomb)
# 	-> result(throw_bomb(bomber),add(bomb))
# resource(bombsleft)
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# resource(lives)
# 	-> result(lose_life,decrease(lives,low))
# 	-> precondition(le(lives,0),lose)
# resource(bomber,duration)
# 	-> entity(bomber)
# 	-> singular(bomber)
# 	-> resource(bomber,direction)
# 	-> resource(bomber,timetilnextbomb)
# 	-> timerlogic(bomber,change_direction,duration,loop)
# 	-> precondition(eq(paused,false),change_direction(bomber))
# 	-> precondition(timer_elapsed(bomber,change_direction),change_direction(bomber))
# 	-> result(change_direction(bomber),set(direction,random_choice(east,west)))
# 	-> timerlogic(bomber,throw_bomb,timetilnextbomb,loop)
# 	-> precondition(eq(paused,false),throw_bomb(bomber))
# 	-> precondition(timer_elapsed(bomber,throw_bomb),throw_bomb(bomber))
# 	-> result(throw_bomb(bomber),add(bomb))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> result(tick,moves(bomber,direction))
# resource(bomber,direction)
# 	-> entity(bomber)
# 	-> singular(bomber)
# 	-> resource(bomber,duration)
# 	-> resource(bomber,timetilnextbomb)
# 	-> timerlogic(bomber,change_direction,duration,loop)
# 	-> precondition(eq(paused,false),change_direction(bomber))
# 	-> precondition(timer_elapsed(bomber,change_direction),change_direction(bomber))
# 	-> result(change_direction(bomber),set(direction,random_choice(east,west)))
# 	-> timerlogic(bomber,throw_bomb,timetilnextbomb,loop)
# 	-> precondition(eq(paused,false),throw_bomb(bomber))
# 	-> precondition(timer_elapsed(bomber,throw_bomb),throw_bomb(bomber))
# 	-> result(throw_bomb(bomber),add(bomb))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> result(tick,moves(bomber,direction))
# resource(bomber,timetilnextbomb)
# 	-> entity(bomber)
# 	-> singular(bomber)
# 	-> resource(bomber,duration)
# 	-> resource(bomber,direction)
# 	-> timerlogic(bomber,change_direction,duration,loop)
# 	-> precondition(eq(paused,false),change_direction(bomber))
# 	-> precondition(timer_elapsed(bomber,change_direction),change_direction(bomber))
# 	-> result(change_direction(bomber),set(direction,random_choice(east,west)))
# 	-> timerlogic(bomber,throw_bomb,timetilnextbomb,loop)
# 	-> precondition(eq(paused,false),throw_bomb(bomber))
# 	-> precondition(timer_elapsed(bomber,throw_bomb),throw_bomb(bomber))
# 	-> result(throw_bomb(bomber),add(bomb))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> result(tick,moves(bomber,direction))
# resource(paused)
# 	-> precondition(eq(paused,false),throw_bomb(bomber))
# 	-> result(lose_life,set(paused,true))
# 	-> precondition(eq(paused,false),tick)
# 	-> precondition(eq(paused,false),change_direction(bomber))
# timerlogic(bomber,change_direction,duration,loop)
# 	-> entity(bomber)
# 	-> singular(bomber)
# 	-> resource(bomber,duration)
# 	-> resource(bomber,direction)
# 	-> resource(bomber,timetilnextbomb)
# 	-> precondition(eq(paused,false),change_direction(bomber))
# 	-> precondition(timer_elapsed(bomber,change_direction),change_direction(bomber))
# 	-> result(change_direction(bomber),set(direction,random_choice(east,west)))
# 	-> timerlogic(bomber,throw_bomb,timetilnextbomb,loop)
# 	-> precondition(eq(paused,false),throw_bomb(bomber))
# 	-> precondition(timer_elapsed(bomber,throw_bomb),throw_bomb(bomber))
# 	-> result(throw_bomb(bomber),add(bomb))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> result(tick,moves(bomber,direction))
# precondition(eq(paused,false),change_direction(bomber))
# 	-> result(lose_life,set(paused,true))
# 	-> entity(bomber)
# 	-> singular(bomber)
# 	-> result(player_serve,set(player_start,false))
# 	-> result(computer_serve,set(computer_start,false))
# 	-> resource(bomber,duration)
# 	-> resource(bomber,direction)
# 	-> resource(bomber,timetilnextbomb)
# 	-> resource(paused)
# 	-> timerlogic(bomber,change_direction,duration,loop)
# 	-> precondition(timer_elapsed(bomber,change_direction),change_direction(bomber))
# 	-> result(change_direction(bomber),set(direction,random_choice(east,west)))
# 	-> timerlogic(bomber,throw_bomb,timetilnextbomb,loop)
# 	-> precondition(eq(paused,false),throw_bomb(bomber))
# 	-> precondition(timer_elapsed(bomber,throw_bomb),throw_bomb(bomber))
# 	-> result(throw_bomb(bomber),add(bomb))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> precondition(eq(paused,false),tick)
# 	-> result(tick,moves(bomber,direction))
# precondition(timer_elapsed(bomber,change_direction),change_direction(bomber))
# 	-> entity(bomber)
# 	-> singular(bomber)
# 	-> resource(bomber,duration)
# 	-> resource(bomber,direction)
# 	-> resource(bomber,timetilnextbomb)
# 	-> timerlogic(bomber,change_direction,duration,loop)
# 	-> precondition(eq(paused,false),change_direction(bomber))
# 	-> result(change_direction(bomber),set(direction,random_choice(east,west)))
# 	-> timerlogic(bomber,throw_bomb,timetilnextbomb,loop)
# 	-> precondition(eq(paused,false),throw_bomb(bomber))
# 	-> precondition(timer_elapsed(bomber,throw_bomb),throw_bomb(bomber))
# 	-> result(throw_bomb(bomber),add(bomb))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> result(tick,moves(bomber,direction))
# result(change_direction(bomber),set(direction,random_choice(east,west)))
# 	-> result(move_right,moves(basket,east,low))
# 	-> entity(bomber)
# 	-> singular(bomber)
# 	-> result(move_left,moves(basket,west,low))
# 	-> resource(bomber,duration)
# 	-> resource(bomber,direction)
# 	-> resource(bomber,timetilnextbomb)
# 	-> timerlogic(bomber,change_direction,duration,loop)
# 	-> precondition(eq(paused,false),change_direction(bomber))
# 	-> precondition(timer_elapsed(bomber,change_direction),change_direction(bomber))
# 	-> timerlogic(bomber,throw_bomb,timetilnextbomb,loop)
# 	-> precondition(eq(paused,false),throw_bomb(bomber))
# 	-> precondition(timer_elapsed(bomber,throw_bomb),throw_bomb(bomber))
# 	-> result(throw_bomb(bomber),add(bomb))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> result(tick,moves(bomber,direction))
# timerlogic(bomber,throw_bomb,timetilnextbomb,loop)
# 	-> entity(bomber)
# 	-> singular(bomber)
# 	-> resource(bomber,duration)
# 	-> resource(bomber,direction)
# 	-> resource(bomber,timetilnextbomb)
# 	-> timerlogic(bomber,change_direction,duration,loop)
# 	-> precondition(eq(paused,false),change_direction(bomber))
# 	-> precondition(timer_elapsed(bomber,change_direction),change_direction(bomber))
# 	-> result(change_direction(bomber),set(direction,random_choice(east,west)))
# 	-> precondition(eq(paused,false),throw_bomb(bomber))
# 	-> precondition(timer_elapsed(bomber,throw_bomb),throw_bomb(bomber))
# 	-> result(throw_bomb(bomber),add(bomb))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> result(tick,moves(bomber,direction))
# precondition(eq(paused,false),throw_bomb(bomber))
# 	-> result(lose_life,set(paused,true))
# 	-> entity(bomber)
# 	-> singular(bomber)
# 	-> result(player_serve,set(player_start,false))
# 	-> result(computer_serve,set(computer_start,false))
# 	-> resource(bomber,duration)
# 	-> resource(bomber,direction)
# 	-> resource(bomber,timetilnextbomb)
# 	-> resource(paused)
# 	-> timerlogic(bomber,change_direction,duration,loop)
# 	-> precondition(eq(paused,false),change_direction(bomber))
# 	-> precondition(timer_elapsed(bomber,change_direction),change_direction(bomber))
# 	-> result(change_direction(bomber),set(direction,random_choice(east,west)))
# 	-> timerlogic(bomber,throw_bomb,timetilnextbomb,loop)
# 	-> precondition(timer_elapsed(bomber,throw_bomb),throw_bomb(bomber))
# 	-> result(throw_bomb(bomber),add(bomb))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> precondition(eq(paused,false),tick)
# 	-> result(tick,moves(bomber,direction))
# precondition(timer_elapsed(bomber,throw_bomb),throw_bomb(bomber))
# 	-> entity(bomber)
# 	-> singular(bomber)
# 	-> resource(bomber,duration)
# 	-> resource(bomber,direction)
# 	-> resource(bomber,timetilnextbomb)
# 	-> timerlogic(bomber,change_direction,duration,loop)
# 	-> precondition(eq(paused,false),change_direction(bomber))
# 	-> precondition(timer_elapsed(bomber,change_direction),change_direction(bomber))
# 	-> result(change_direction(bomber),set(direction,random_choice(east,west)))
# 	-> timerlogic(bomber,throw_bomb,timetilnextbomb,loop)
# 	-> precondition(eq(paused,false),throw_bomb(bomber))
# 	-> result(throw_bomb(bomber),add(bomb))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> result(tick,moves(bomber,direction))
# result(throw_bomb(bomber),add(bomb))
# 	-> result(tick,moves(bomb,south))
# 	-> precondition(overlaps(bomb,basket),defuse)
# 	-> result(defuse,delete(bomb))
# 	-> entity(bomber)
# 	-> precondition(overlaps(bomb,screen_bottom),lose_life)
# 	-> entity(bomb)
# 	-> singular(bomber)
# 	-> many(bomb)
# 	-> resource(bomber,duration)
# 	-> resource(bomber,direction)
# 	-> resource(bomber,timetilnextbomb)
# 	-> timerlogic(bomber,change_direction,duration,loop)
# 	-> precondition(eq(paused,false),change_direction(bomber))
# 	-> precondition(timer_elapsed(bomber,change_direction),change_direction(bomber))
# 	-> result(change_direction(bomber),set(direction,random_choice(east,west)))
# 	-> timerlogic(bomber,throw_bomb,timetilnextbomb,loop)
# 	-> precondition(eq(paused,false),throw_bomb(bomber))
# 	-> precondition(timer_elapsed(bomber,throw_bomb),throw_bomb(bomber))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> result(tick,moves(bomber,direction))
# result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> result(move_up,moves(paddle_player,north,low))
# 	-> result(move_down,moves(paddle_player,south,low))
# 	-> result(move_up_computer,moves(paddle_computer,north,low))
# 	-> result(move_down_computer,moves(paddle_computer,south,low))
# 	-> result(computer_score,increase(score_computer,low))
# 	-> result(player_score,increase(score_player,low))
# 	-> entity(bomber)
# 	-> singular(bomber)
# 	-> resource(bombsleft)
# 	-> resource(bomber,duration)
# 	-> resource(bomber,direction)
# 	-> resource(bomber,timetilnextbomb)
# 	-> timerlogic(bomber,change_direction,duration,loop)
# 	-> precondition(eq(paused,false),change_direction(bomber))
# 	-> precondition(timer_elapsed(bomber,change_direction),change_direction(bomber))
# 	-> result(change_direction(bomber),set(direction,random_choice(east,west)))
# 	-> timerlogic(bomber,throw_bomb,timetilnextbomb,loop)
# 	-> precondition(eq(paused,false),throw_bomb(bomber))
# 	-> precondition(timer_elapsed(bomber,throw_bomb),throw_bomb(bomber))
# 	-> result(throw_bomb(bomber),add(bomb))
# 	-> result(tick,moves(bomber,direction))
# 	-> result(defuse,increase(score,low))
# 	-> result(move_right,moves(basket,east,low))
# 	-> result(move_left,moves(basket,west,low))
# 	-> result(lose_life,decrease(lives,low))
# precondition(eq(paused,false),tick)
# 	-> result(tick,moves(bomb,south))
# 	-> result(lose_life,set(paused,true))
# 	-> result(player_serve,set(player_start,false))
# 	-> result(computer_serve,set(computer_start,false))
# 	-> resource(paused)
# 	-> precondition(eq(paused,false),change_direction(bomber))
# 	-> precondition(eq(paused,false),throw_bomb(bomber))
# 	-> result(tick,moves(bomber,direction))
# result(tick,moves(bomber,direction))
# 	-> result(tick,moves(bomb,south))
# 	-> entity(bomber)
# 	-> singular(bomber)
# 	-> resource(bomber,duration)
# 	-> resource(bomber,direction)
# 	-> resource(bomber,timetilnextbomb)
# 	-> timerlogic(bomber,change_direction,duration,loop)
# 	-> precondition(eq(paused,false),change_direction(bomber))
# 	-> precondition(timer_elapsed(bomber,change_direction),change_direction(bomber))
# 	-> result(change_direction(bomber),set(direction,random_choice(east,west)))
# 	-> timerlogic(bomber,throw_bomb,timetilnextbomb,loop)
# 	-> precondition(eq(paused,false),throw_bomb(bomber))
# 	-> precondition(timer_elapsed(bomber,throw_bomb),throw_bomb(bomber))
# 	-> result(throw_bomb(bomber),add(bomb))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> precondition(eq(paused,false),tick)
# result(tick,moves(bomb,south))
# 	-> precondition(overlaps(bomb,basket),defuse)
# 	-> result(defuse,delete(bomb))
# 	-> precondition(overlaps(bomb,screen_bottom),lose_life)
# 	-> entity(bomb)
# 	-> many(bomb)
# 	-> result(move_down,moves(paddle_player,south,low))
# 	-> result(move_down_computer,moves(paddle_computer,south,low))
# 	-> result(throw_bomb(bomber),add(bomb))
# 	-> precondition(eq(paused,false),tick)
# 	-> result(tick,moves(bomber,direction))
# precondition(overlaps(bomb,basket),defuse)
# 	-> result(tick,moves(bomb,south))
# 	-> result(defuse,delete(bomb))
# 	-> result(defuse,increase(score,low))
# 	-> result(move_right,moves(basket,east,low))
# 	-> result(move_left,moves(basket,west,low))
# 	-> entity(basket)
# 	-> entity(bomb)
# 	-> singular(basket)
# 	-> many(bomb)
# 	-> precondition(overlaps(bomb,screen_bottom),lose_life)
# 	-> result(throw_bomb(bomber),add(bomb))
# 	-> player_controls(basket)
# result(defuse,delete(bomb))
# 	-> result(tick,moves(bomb,south))
# 	-> precondition(overlaps(bomb,basket),defuse)
# 	-> result(defuse,increase(score,low))
# 	-> precondition(overlaps(bomb,screen_bottom),lose_life)
# 	-> entity(bomb)
# 	-> many(bomb)
# 	-> result(throw_bomb(bomber),add(bomb))
# result(defuse,increase(score,low))
# 	-> precondition(overlaps(bomb,basket),defuse)
# 	-> result(defuse,delete(bomb))
# 	-> result(move_right,moves(basket,east,low))
# 	-> result(move_left,moves(basket,west,low))
# 	-> result(lose_life,decrease(lives,low))
# 	-> result(player_score,increase(score_player,low))
# 	-> result(move_up,moves(paddle_player,north,low))
# 	-> result(move_down,moves(paddle_player,south,low))
# 	-> result(move_up_computer,moves(paddle_computer,north,low))
# 	-> result(move_down_computer,moves(paddle_computer,south,low))
# 	-> result(computer_score,increase(score_computer,low))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# precondition(control_event(player_input(right_arrow,held)),move_right)
# 	-> precondition(control_event(player_input(up_arrow,held)),move_up)
# 	-> precondition(control_event(player_input(down_arrow,held)),move_down)
# 	-> result(move_right,moves(basket,east,low))
# 	-> precondition(control_event(player_input(left_arrow,held)),move_left)
# result(move_right,moves(basket,east,low))
# 	-> precondition(overlaps(bomb,basket),defuse)
# 	-> result(player_score,increase(score_player,low))
# 	-> result(defuse,increase(score,low))
# 	-> precondition(control_event(player_input(right_arrow,held)),move_right)
# 	-> result(move_left,moves(basket,west,low))
# 	-> entity(basket)
# 	-> result(lose_life,decrease(lives,low))
# 	-> singular(basket)
# 	-> result(move_down_computer,moves(paddle_computer,south,low))
# 	-> result(move_up,moves(paddle_player,north,low))
# 	-> result(move_down,moves(paddle_player,south,low))
# 	-> result(move_up_computer,moves(paddle_computer,north,low))
# 	-> result(change_direction(bomber),set(direction,random_choice(east,west)))
# 	-> result(computer_score,increase(score_computer,low))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> player_controls(basket)
# precondition(control_event(player_input(left_arrow,held)),move_left)
# 	-> precondition(control_event(player_input(up_arrow,held)),move_up)
# 	-> precondition(control_event(player_input(down_arrow,held)),move_down)
# 	-> precondition(control_event(player_input(right_arrow,held)),move_right)
# 	-> result(move_left,moves(basket,west,low))
# result(move_left,moves(basket,west,low))
# 	-> precondition(overlaps(bomb,basket),defuse)
# 	-> result(player_score,increase(score_player,low))
# 	-> result(defuse,increase(score,low))
# 	-> result(move_right,moves(basket,east,low))
# 	-> precondition(control_event(player_input(left_arrow,held)),move_left)
# 	-> entity(basket)
# 	-> result(lose_life,decrease(lives,low))
# 	-> singular(basket)
# 	-> result(move_down_computer,moves(paddle_computer,south,low))
# 	-> result(move_up,moves(paddle_player,north,low))
# 	-> result(move_down,moves(paddle_player,south,low))
# 	-> result(move_up_computer,moves(paddle_computer,north,low))
# 	-> result(change_direction(bomber),set(direction,random_choice(east,west)))
# 	-> result(computer_score,increase(score_computer,low))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# 	-> player_controls(basket)
# precondition(overlaps(bomb,screen_bottom),lose_life)
# 	-> result(tick,moves(bomb,south))
# 	-> precondition(overlaps(bomb,basket),defuse)
# 	-> result(defuse,delete(bomb))
# 	-> entity(bomb)
# 	-> result(lose_life,set(paused,true))
# 	-> many(bomb)
# 	-> result(lose_life,decrease(lives,low))
# 	-> result(throw_bomb(bomber),add(bomb))
# result(lose_life,decrease(lives,low))
# 	-> result(player_score,increase(score_player,low))
# 	-> result(defuse,increase(score,low))
# 	-> result(move_right,moves(basket,east,low))
# 	-> result(move_left,moves(basket,west,low))
# 	-> precondition(overlaps(bomb,screen_bottom),lose_life)
# 	-> result(lose_life,set(paused,true))
# 	-> precondition(le(lives,0),lose)
# 	-> resource(lives)
# 	-> result(move_up,moves(paddle_player,north,low))
# 	-> result(move_down,moves(paddle_player,south,low))
# 	-> result(move_up_computer,moves(paddle_computer,north,low))
# 	-> result(move_down_computer,moves(paddle_computer,south,low))
# 	-> result(computer_score,increase(score_computer,low))
# 	-> result(throw_bomb(bomber),decrease(bombsleft,low))
# result(lose_life,set(paused,true))
# 	-> result(player_score,set(player_start,true))
# 	-> precondition(overlaps(bomb,screen_bottom),lose_life)
# 	-> result(lose_life,decrease(lives,low))
# 	-> precondition(eq(player_start,true),player_serve)
# 	-> precondition(eq(computer_start,true),computer_serve)
# 	-> resource(paused)
# 	-> precondition(eq(paused,false),change_direction(bomber))
# 	-> precondition(eq(paused,false),throw_bomb(bomber))
# 	-> result(computer_score,set(player_start,true))
# 	-> precondition(eq(paused,false),tick)
# precondition(le(lives,0),lose)
# 	-> resource(lives)
# 	-> result(lose_life,decrease(lives,low))
# 	-> result(lose,mode_change(game_loss))
# 	-> precondition(ge(score_computer,high),lose)
# 	-> result(lose,mode_change(game_loss))
# result(lose,mode_change(game_loss))
# 	-> precondition(le(lives,0),lose)
# 	-> precondition(ge(score_computer,high),lose)
# 	-> result(lose,mode_change(game_loss))

# %%
def coarsenings(head,body):
    possible_coarsenings = []
    all_high_level_terms = set()
    term_usage = {}
    terms = get_terms(head)
    for term in terms:
        if term not in term_usage:
            term_usage[term] = []
        term_usage[term].append(-1)


    for pred_id,predicate in enumerate(body):
        high_level_terms = get_higher_level(predicate)
        all_high_level_terms |= set(high_level_terms)
        terms = get_terms(predicate)
        for term in terms:
            if term not in term_usage:
                term_usage[term] = []
            term_usage[term].append(pred_id)
    safe_terms = set(all_high_level_terms)

    for high_level in all_high_level_terms:
        for term in term_usage:
            if len(term_usage[term]) > 1 and term in high_level:
                safe_terms.remove(high_level)
                break

    return list(safe_terms)

def coarsen(coarsenings_,body):
    new_rules = []
    coarsening2ind = {coarsening:'V{}'.format(i) for i,coarsening in enumerate(coarsenings_)}
    ind2coarsening = {'V{}'.format(i):coarsening for i,coarsening in enumerate(coarsenings_)}

    new_body = []
    for b in body:

        pretty_b = prettify(b)
        for i in sorted(ind2coarsening):
            c = ind2coarsening[i]
            pretty_b = pretty_b.replace(c,i)

        new_body.append(parse_terms(pretty_b)[0][0])
    return new_body

# %%
import itertools

def get_neighbors(points,connections,rules):
    neighbors = set()
    
    for point in points:
        for conn in connections[point]:
            neighbors.add(tuple(sorted(set(points) | set([conn]))))
    return neighbors

def get_all_combinations(points,lhs,rules):
    rules_to_use = [rules[point] for point in points]
    uniques = set()
        
    for fact_id, fact in enumerate(rules_to_use):
        terms = set(get_terms(fact))
        uniques |= terms #set([(fact_id,term) for term in terms])
    unique_combos = []
    for ii in range(0,len(uniques)+1):
        unique_combos += list(itertools.combinations(uniques,ii))
    output = []
    for uniques in unique_combos:   
        uniques = sorted(uniques)
        unique_mapping = {}
        can_be_used_by_type = {}
        for unique_id,u in enumerate(uniques):
            t = types[u.lower()]
            if t not in can_be_used_by_type:
                can_be_used_by_type[t] = []
            unique_mapping[u] = 'V{}{}'.format(t,unique_id) #random.randint(0,len(by_type[t])))
            can_be_used_by_type[t].append(unique_mapping[u])
        final_facts = [] 
        for fact_id, fact in enumerate(rules_to_use):            
            terms = set(get_terms(fact))
            for term in terms:
                if term in unique_mapping:
                    fact = replace(fact,term,unique_mapping[term])
            final_facts.append(fact)
        target_form = lhs
        terms = list(set(get_terms(target_form)))
        for term in terms:
            if term in unique_mapping:
                target_form = replace(target_form,term,unique_mapping[term])
        potential_coarsenings = coarsenings(target_form,final_facts)
        
        coarsening_combos = []
        for ii in range(0, len(potential_coarsenings)+1):
            coarsening_combos += list(itertools.combinations(potential_coarsenings,ii))
        
        for coarsening in sorted(coarsening_combos):
            
            coarsened = coarsen(coarsening,final_facts)
            
            
        
            by_term = {}
            for fact_id, fact in enumerate(coarsened):
                terms = set(get_terms(fact))
                for term in terms:
                    if term not in by_term:
                        by_term[term] = set()
                    by_term[term].add(fact_id)
                    
            able_to_be_negated = []
            for fact_id, fact in enumerate(coarsened):
                terms = set(get_terms(fact))
                can_be_negated = True
                for term in terms:
                    if len(by_term[term]) == 1:
                        can_be_negated = False
                        break
                if can_be_negated:
                    able_to_be_negated.append(fact_id)
            
            negation_combos = []
            for ii in range(0,len(able_to_be_negated)+1):
                negation_combos  += list(itertools.combinations(able_to_be_negated,ii))
            
            
            for negation_combo in negation_combos:
                negations = [False]*len(coarsened)
                for n in negation_combo:
                    negations[n] = True
                output.append((target_form,coarsened,negations))
    return output

def score_rule(games,rule,per_game_positives):
    head, body, negations = rule
    probability = 0
    for game,positives in zip(games,per_game_positives):
            
        rule_string = '.\n'.join(game)
        
        
        rule_string += '.\n' + rule_to_string(rule)
        hashed_name = 'temp' + hashlib.sha224(rule_string).hexdigest()
        with open(hashed_name,'wb') as outfile:
            outfile.write('.\n'.join(game) + '.\n')
            outfile.write(rule_to_string(rule))
            outfile.write('#show {}/{}.'.format(head['predicate'],len(head['terms'])))
                
        
        solved = solve([hashed_name])
        
        is_good = True
        found = []
        total_found = 0
        for t in solved:
            for tt in solved[t]:
                for ttt in tt:
                    if prettify(ttt) in positives:
                        found.append(prettify(ttt))
                    else:
                        is_good = False
                        break
                if not is_good:
                    break
            if not is_good:
                break
            if is_good:
                total_found += 1
        if is_good:
            if total_found == 0:
                probability += np.log(1e-20)
            else:
                probability += np.log(float(total_found)/float(len(positives)))
        else:
            probability += np.log(1e-20)
        
    return -probability
def rule_to_string(rule):
    head,body,negations = rule
    
    rule_text = []
    for n,r in zip(negations,body):
        if n:
            rule_text.append('not '+prettify(r))
        else:
            rule_text.append(prettify(r))
    return prettify(head) + ':-' + ','.join(list(sorted(rule_text))) + '.\n'
def breadth_first(connections,rules):    
    starting_points = []
    for connection in sorted(connections):
        if connection < 0:
            starting_points.append([connection])
            
    to_visit = [tuple(pt) for pt in starting_points]
    max_size = 3
    tested_rules = set()
    visited = set()
    visited |= set(to_visit)
    while len(to_visit) > 0:
        current = to_visit.pop(0)
        if len(current) > max_size:
            break
            
        lhses = [c for c in current if c < 0]
        to_test = []
        for lhs in lhses:
            if len(current) > 1:
                shrunk = set(current)
                shrunk.remove(lhs)
                to_test += get_all_combinations(shrunk,rules[lhs],rules)                
            #to_test += get_all_combinations(current,rules[lhs],rules)
        scored_rules = {}
        
        
        for rule in to_test:
            terms = get_terms(rule[0])
            
            for r in rule[1]:
                terms += get_terms(r)
            terms = set(terms)
            specifics = 0
            general = 0
            for term in terms:
                if term[0].islower():
                    specifics +=1
                else:
                    general += 1
            score = 1000*specifics+general
            if score not in scored_rules:
                scored_rules[score] = {}
                
            rule_string = rule_to_string(rule)
            
            if rule_string not in tested_rules:
                scored_rules[score][rule_to_string(rule)] = rule
                tested_rules.add(rule_string)
                #print 'testing', rule_string
        
        
        for score in sorted(scored_rules):
            for rule in scored_rules[score].values():
                log_prob = score_rule(games,rule,all_positives)
                if log_prob < 46 :
                    print score,log_prob
                    print prettify(rule[0]) , ':-'
                    for r in rule[1]:
                        print '\t', prettify(r)
                    print ''
                    if log_prob < 0.0001:
                        return rule
                
            
        neighbors = get_neighbors(current,connections,rules)
        neighbors = [tuple(sorted(neighbor)) for neighbor in neighbors]
        neighbors = [neighbor for neighbor in neighbors if neighbor not in visited]
        visited |= set(neighbors)
        to_visit += neighbors

breadth_first(connections,rules)
# Out:
# 5 -0.0
# player_controls(Ventity0) :-
# 	precondition(control_event(V0),Voutcome4)
# 	result(Voutcome4,moves(Ventity0,Vdirection5,Vscalar3))
# ({'predicate': 'player_controls', 'terms': [{'predicate': 'Ventity0'}]},
#  [{'predicate': 'precondition',
#    'terms': [{'predicate': 'control_event', 'terms': [{'predicate': 'V0'}]},
#     {'predicate': 'Voutcome4'}]},
#   {'predicate': 'result',
#    'terms': [{'predicate': 'Voutcome4'},
#     {'predicate': 'moves',
#      'terms': [{'predicate': 'Ventity0'},
#       {'predicate': 'Vdirection5'},
#       {'predicate': 'Vscalar3'}]}]}],
#  [False, False])
