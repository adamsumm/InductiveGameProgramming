# %%
import json
import collections
import subprocess

def prettify(atom):

    s = atom['predicate']
    if 'terms' in atom:
        s += '('
        ts = [prettify(t) for t in atom['terms']]
        s += ','.join(ts)
        s += ')'
    return s

  
def parse_json_result(out):
    """Parse the provided JSON text and extract a dict
    representing the predicates described in the first solver result."""
    result = json.loads(out)
    assert len(result['Call']) > 0
    assert len(result['Call'][0]['Witnesses']) > 0
    all_preds = []
    ids = range(len(result['Call'][0]['Witnesses']))
    
    witness = result['Call'][0]['Witnesses'][0]['Value']

    class identitydefaultdict(collections.defaultdict):
        def __missing__(self, key):
            return key

    preds = collections.defaultdict(list)
    env = identitydefaultdict()

    for atom in witness:
        parsed,dummy = parse_terms(atom)
        preds[parsed[0]['predicate']].append(parsed)
    return preds

def solve(args):
    """Run clingo with the provided argument list and return the parsed JSON result."""

    args = ['clingo','--outf=2'] + args
    clingo = subprocess.Popen(
        ' '.join(args),
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE,
        shell=True
        )
    out, err = clingo.communicate()
            
    return parse_json_result(out)

def parse_terms(arguments):
    terms = []
    while len(arguments) > 0:
        l_paren = arguments.find('(')
        r_paren = arguments.find(')')
        comma = arguments.find(',')
        if l_paren < 0:
            l_paren = len(arguments)-1
        if r_paren < 0:
            r_paren = len(arguments)-1
        if comma < 0:
            comma = len(arguments)-1
        next = min(l_paren,r_paren,comma)
        next_c = arguments[next]
        if next_c == '(':
        
            pred = arguments[:next]
            sub_terms, arguments = parse_terms(arguments[next+1:]) 
            terms.append({'predicate':pred,'terms':sub_terms})
        elif next_c == ')':
            pred = arguments[:next]
            if pred != '':
                terms.append({'predicate':arguments[:next]})
            arguments = arguments[next+1:]
            return terms,arguments
        elif next_c == ',':
            pred = arguments[:next]
            if pred != '':
                terms.append({'predicate':arguments[:next]})
            arguments = arguments[next+1:]
        else:
            terms.append({'predicate':arguments})
            arguments = ''
    return terms, ''

# %%
filename = 'pong.lp'

rules = open(filename,'rb').read().replace(' ','').replace('\n','').split('.')[:-1]
rules = [parse_terms(rule)[0][0] for rule in rules]
facts = []
types = {}
for rule in rules:
    print rule
    if rule['predicate'] == 'type':
        print rule
        types[rule['terms'][1]['predicate']] = rule['terms'][0]['predicate']
    else: 
        facts.append(rule)
output_rules = [prettify(rule) for rule in facts]
print types
# Out:
# {'predicate': 'type', 'terms': [{'predicate': 'boolean'}, {'predicate': 'boolean'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'boolean'}, {'predicate': 'boolean'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'boolean'}, {'predicate': 'false'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'boolean'}, {'predicate': 'false'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'boolean'}, {'predicate': 'true'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'boolean'}, {'predicate': 'true'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'boundary'}, {'predicate': 'boundary'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'boundary'}, {'predicate': 'boundary'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'boundary'}, {'predicate': 'screen_left'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'boundary'}, {'predicate': 'screen_left'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'boundary'}, {'predicate': 'screen_right'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'boundary'}, {'predicate': 'screen_right'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'direction'}, {'predicate': 'direction'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'direction'}, {'predicate': 'direction'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'direction'}, {'predicate': 'north'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'direction'}, {'predicate': 'north'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'direction'}, {'predicate': 'north_east'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'direction'}, {'predicate': 'north_east'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'direction'}, {'predicate': 'north_west'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'direction'}, {'predicate': 'north_west'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'direction'}, {'predicate': 'vector'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'direction'}, {'predicate': 'vector'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'direction'}, {'predicate': 'south'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'direction'}, {'predicate': 'south'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'entity'}, {'predicate': 'ball'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'entity'}, {'predicate': 'ball'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'entity'}, {'predicate': 'entity'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'entity'}, {'predicate': 'entity'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'entity'}, {'predicate': 'paddle_computer'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'entity'}, {'predicate': 'paddle_computer'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'entity'}, {'predicate': 'paddle_player'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'entity'}, {'predicate': 'paddle_player'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'key'}, {'predicate': 'down_arrow'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'key'}, {'predicate': 'down_arrow'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'key'}, {'predicate': 'key'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'key'}, {'predicate': 'key'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'key'}, {'predicate': 'space'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'key'}, {'predicate': 'space'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'key'}, {'predicate': 'up_arrow'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'key'}, {'predicate': 'up_arrow'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'mode'}, {'predicate': 'game_loss'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'mode'}, {'predicate': 'game_loss'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'mode'}, {'predicate': 'game_win'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'mode'}, {'predicate': 'game_win'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'mode'}, {'predicate': 'mode_change'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'mode'}, {'predicate': 'mode_change'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'computer_hit'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'computer_hit'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'computer_score'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'computer_score'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'computer_serve'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'computer_serve'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'lose'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'lose'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'move_down'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'move_down'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'move_down_computer'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'move_down_computer'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'move_up'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'move_up'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'move_up_computer'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'move_up_computer'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'outcome'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'outcome'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'player_hit'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'player_hit'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'player_score'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'player_score'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'player_serve'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'player_serve'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'win'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'outcome'}, {'predicate': 'win'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'press_type'}, {'predicate': 'held'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'press_type'}, {'predicate': 'held'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'press_type'}, {'predicate': 'pressed'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'press_type'}, {'predicate': 'pressed'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'press_type'}, {'predicate': 'press_type'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'press_type'}, {'predicate': 'press_type'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'resource'}, {'predicate': 'computer_start'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'resource'}, {'predicate': 'computer_start'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'resource'}, {'predicate': 'player_start'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'resource'}, {'predicate': 'player_start'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'resource'}, {'predicate': 'resource'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'resource'}, {'predicate': 'resource'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'resource'}, {'predicate': 'score_computer'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'resource'}, {'predicate': 'score_computer'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'resource'}, {'predicate': 'score_player'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'resource'}, {'predicate': 'score_player'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'scalar'}, {'predicate': 'high'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'scalar'}, {'predicate': 'high'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'scalar'}, {'predicate': 'low'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'scalar'}, {'predicate': 'low'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'scalar'}, {'predicate': 'scalar'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'scalar'}, {'predicate': 'scalar'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'entity'}, {'predicate': 'singular'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'entity'}, {'predicate': 'singular'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'control_event'}, {'predicate': 'player_input'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'control_event'}, {'predicate': 'player_input'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'control_event'}, {'predicate': 'control_event'}]}
# {'predicate': 'type', 'terms': [{'predicate': 'control_event'}, {'predicate': 'control_event'}]}
# {'predicate': 'entity', 'terms': [{'predicate': 'ball'}]}
# {'predicate': 'entity', 'terms': [{'predicate': 'paddle_player'}]}
# {'predicate': 'entity', 'terms': [{'predicate': 'paddle_computer'}]}
# {'predicate': 'singular', 'terms': [{'predicate': 'ball'}]}
# {'predicate': 'singular', 'terms': [{'predicate': 'paddle_player'}]}
# {'predicate': 'singular', 'terms': [{'predicate': 'paddle_computer'}]}
# {'predicate': 'resource', 'terms': [{'predicate': 'score_player'}]}
# {'predicate': 'resource', 'terms': [{'predicate': 'score_computer'}]}
# {'predicate': 'resource', 'terms': [{'predicate': 'player_start'}]}
# {'predicate': 'resource', 'terms': [{'predicate': 'computer_start'}]}
# {'predicate': 'precondition', 'terms': [{'predicate': 'eq', 'terms': [{'predicate': 'player_start'}, {'predicate': 'true'}]}, {'predicate': 'player_serve'}]}
# {'predicate': 'precondition', 'terms': [{'predicate': 'control_event', 'terms': [{'predicate': 'player_input', 'terms': [{'predicate': 'space'}, {'predicate': 'pressed'}]}]}, {'predicate': 'player_serve'}]}
# {'predicate': 'result', 'terms': [{'predicate': 'player_serve'}, {'predicate': 'set', 'terms': [{'predicate': 'player_start'}, {'predicate': 'false'}]}]}
# {'predicate': 'result', 'terms': [{'predicate': 'player_serve'}, {'predicate': 'apply_impulse', 'terms': [{'predicate': 'ball'}, {'predicate': 'vector', 'terms': [{'predicate': 'north_east'}]}]}]}
# {'predicate': 'precondition', 'terms': [{'predicate': 'eq', 'terms': [{'predicate': 'computer_start'}, {'predicate': 'true'}]}, {'predicate': 'computer_serve'}]}
# {'predicate': 'result', 'terms': [{'predicate': 'computer_serve'}, {'predicate': 'set', 'terms': [{'predicate': 'computer_start'}, {'predicate': 'false'}]}]}
# {'predicate': 'result', 'terms': [{'predicate': 'computer_serve'}, {'predicate': 'apply_impulse', 'terms': [{'predicate': 'ball'}, {'predicate': 'vector', 'terms': [{'predicate': 'north_west'}]}]}]}
# {'predicate': 'precondition', 'terms': [{'predicate': 'control_event', 'terms': [{'predicate': 'player_input', 'terms': [{'predicate': 'up_arrow'}, {'predicate': 'held'}]}]}, {'predicate': 'move_up'}]}
# {'predicate': 'result', 'terms': [{'predicate': 'move_up'}, {'predicate': 'moves', 'terms': [{'predicate': 'paddle_player'}, {'predicate': 'north'}, {'predicate': 'low'}]}]}
# {'predicate': 'precondition', 'terms': [{'predicate': 'control_event', 'terms': [{'predicate': 'player_input', 'terms': [{'predicate': 'down_arrow'}, {'predicate': 'held'}]}]}, {'predicate': 'move_down'}]}
# {'predicate': 'result', 'terms': [{'predicate': 'move_down'}, {'predicate': 'moves', 'terms': [{'predicate': 'paddle_player'}, {'predicate': 'south'}, {'predicate': 'low'}]}]}
# {'predicate': 'precondition', 'terms': [{'predicate': 'above', 'terms': [{'predicate': 'paddle_computer'}, {'predicate': 'ball'}]}, {'predicate': 'move_up_computer'}]}
# {'predicate': 'result', 'terms': [{'predicate': 'move_up_computer'}, {'predicate': 'moves', 'terms': [{'predicate': 'paddle_computer'}, {'predicate': 'north'}, {'predicate': 'low'}]}]}
# {'predicate': 'precondition', 'terms': [{'predicate': 'below', 'terms': [{'predicate': 'paddle_computer'}, {'predicate': 'ball'}]}, {'predicate': 'move_down_computer'}]}
# {'predicate': 'result', 'terms': [{'predicate': 'move_down_computer'}, {'predicate': 'moves', 'terms': [{'predicate': 'paddle_computer'}, {'predicate': 'south'}, {'predicate': 'low'}]}]}
# {'predicate': 'precondition', 'terms': [{'predicate': 'overlaps', 'terms': [{'predicate': 'ball'}, {'predicate': 'screen_left'}]}, {'predicate': 'computer_score'}]}
# {'predicate': 'result', 'terms': [{'predicate': 'computer_score'}, {'predicate': 'set', 'terms': [{'predicate': 'player_start'}, {'predicate': 'true'}]}]}
# {'predicate': 'result', 'terms': [{'predicate': 'computer_score'}, {'predicate': 'increase', 'terms': [{'predicate': 'score_computer'}, {'predicate': 'low'}]}]}
# {'predicate': 'precondition', 'terms': [{'predicate': 'overlaps', 'terms': [{'predicate': 'ball'}, {'predicate': 'paddle_computer'}]}, {'predicate': 'computer_hit'}]}
# {'predicate': 'result', 'terms': [{'predicate': 'computer_hit'}, {'predicate': 'reflect_velocity', 'terms': [{'predicate': 'ball'}, {'predicate': 'collision_normal', 'terms': [{'predicate': 'ball'}, {'predicate': 'paddle_computer'}]}]}]}
# {'predicate': 'precondition', 'terms': [{'predicate': 'overlaps', 'terms': [{'predicate': 'ball'}, {'predicate': 'paddle_player'}]}, {'predicate': 'player_hit'}]}
# {'predicate': 'result', 'terms': [{'predicate': 'player_hit'}, {'predicate': 'reflect_velocity', 'terms': [{'predicate': 'ball'}, {'predicate': 'collision_normal', 'terms': [{'predicate': 'ball'}, {'predicate': 'player_hit'}]}]}]}
# {'predicate': 'precondition', 'terms': [{'predicate': 'overlaps', 'terms': [{'predicate': 'ball'}, {'predicate': 'screen_right'}]}, {'predicate': 'player_score'}]}
# {'predicate': 'result', 'terms': [{'predicate': 'player_score'}, {'predicate': 'set', 'terms': [{'predicate': 'player_start'}, {'predicate': 'true'}]}]}
# {'predicate': 'result', 'terms': [{'predicate': 'player_score'}, {'predicate': 'increase', 'terms': [{'predicate': 'score_player'}, {'predicate': 'low'}]}]}
# {'predicate': 'precondition', 'terms': [{'predicate': 'ge', 'terms': [{'predicate': 'score_player'}, {'predicate': 'high'}]}, {'predicate': 'win'}]}
# {'predicate': 'result', 'terms': [{'predicate': 'win'}, {'predicate': 'mode_change', 'terms': [{'predicate': 'game_win'}]}]}
# {'predicate': 'precondition', 'terms': [{'predicate': 'ge', 'terms': [{'predicate': 'score_computer'}, {'predicate': 'high'}]}, {'predicate': 'lose'}]}
# {'predicate': 'result', 'terms': [{'predicate': 'lose'}, {'predicate': 'mode_change', 'terms': [{'predicate': 'game_loss'}]}]}
# {'up_arrow': 'key', 'player_input': 'control_event', 'false': 'boolean', 'control_event': 'control_event', 'mode_change': 'mode', 'player_score': 'outcome', 'win': 'outcome', 'move_down_computer': 'outcome', 'computer_score': 'outcome', 'screen_right': 'boundary', 'high': 'scalar', 'held': 'press_type', 'scalar': 'scalar', 'boolean': 'boolean', 'move_up_computer': 'outcome', 'down_arrow': 'key', 'move_up': 'outcome', 'player_start': 'resource', 'paddle_computer': 'entity', 'player_serve': 'outcome', 'player_hit': 'outcome', 'move_down': 'outcome', 'low': 'scalar', 'boundary': 'boundary', 'north_west': 'direction', 'game_win': 'mode', 'pressed': 'press_type', 'game_loss': 'mode', 'direction': 'direction', 'ball': 'entity', 'north': 'direction', 'singular': 'entity', 'computer_start': 'resource', 'north_east': 'direction', 'score_player': 'resource', 'key': 'key', 'entity': 'entity', 'true': 'boolean', 'press_type': 'press_type', 'resource': 'resource', 'space': 'key', 'score_computer': 'resource', 'paddle_player': 'entity', 'screen_left': 'boundary', 'computer_serve': 'outcome', 'vector': 'direction', 'computer_hit': 'outcome', 'lose': 'outcome', 'outcome': 'outcome', 'south': 'direction'}

# %%
def has_term(rule,term):
    
    if 'terms' in rule:
        
        for rule_term in rule['terms']:
                if has_term(rule_term,term):
                    return True
        return False
    elif rule['predicate'] == term:
        return True
    else:
        return False
def get_terms(rule):
    if 'terms' in rule:
        terms = []
        for rule_term in rule['terms']:
            terms += get_terms(rule_term)
        return terms
    else:
        return [rule['predicate']]

# %%
import random
import sys

def generalize(fact,probability=0.5):   
        
    if 'terms' in fact:
        terms = []
        if len(fact['terms']) == 1 and random.random()*2 < probability:
            return {'predicate':fact['predicate'],
                'terms':[{'predicate':
                        fact['predicate'].upper()}]}
        for fact_term in fact['terms']:
            terms.append(generalize(fact_term,probability))
        return {'predicate':fact['predicate'],
                'terms':terms}
    else:
        pred = str(fact['predicate'])
        if random.random() < probability:
            pred = pred.upper()
        return {'predicate':pred}
    
def replace(fact,source,target):
    if 'terms' in fact:
        terms = []
        for fact_term in fact['terms']:
            terms.append(replace(fact_term,source,target))
        return {'predicate':fact['predicate'],
                'terms':terms}
    else:
        pred = fact['predicate']
        if pred == source:
            pred = target
        return {'predicate':pred}
    
def generate_rule(target_form,facts,predecessor=None):
    if predecessor:
        pass
    else:
        number_of_rules = random.randrange(2,3)
        random.shuffle(facts)
        facts_to_use = [generalize(fact,0.8) for fact in facts[:number_of_rules]]
        uniques = set()
        
        for fact_id, fact in enumerate(facts_to_use):
            terms = set(get_terms(fact))
            uniques |= set([(fact_id,term) for term in terms])
            
        by_type = {}
        for u in uniques:
            t = types[u[1].lower()]
            if t not in by_type:
                by_type[t] = []
            by_type[t].append(u)
            
        
        unique_mapping = {}
        can_be_used_by_type = {}
        for u in uniques:
            t = types[u[1].lower()]
            if t not in can_be_used_by_type:
                can_be_used_by_type[t] = []
            unique_mapping[u] = 'V{}{}'.format(t,random.randrange(len(by_type[t])))
            can_be_used_by_type[t].append(unique_mapping[u])
            
        by_rule_mapping = {}
        
        for u,m in unique_mapping.items():
            if u[0] not in by_rule_mapping:
                by_rule_mapping[u[0]] = {}
            by_rule_mapping[u[0]][u[1]] = m
            
            
            
        final_facts = [] 
        
        for fact_id, fact in enumerate(facts_to_use):
            
            terms = set(get_terms(fact))
            for term in terms:
                fact = replace(fact,term,by_rule_mapping[fact_id][term])
            final_facts.append(fact)
        
        terms = list(set(get_terms(target_form)))
        for term in terms:
            if term not in can_be_used_by_type:
                return (None,None)
            target_form = replace(target_form,term,random.choice(can_be_used_by_type[term]))
        return target_form,final_facts
        
target_rule  = {'predicate':'player_controls','terms':[{'predicate':'entity'}]}



positives = [{'predicate':'player_controls','terms':[{'predicate':'paddle_player'}]}]
positives = [prettify(f) for f in positives]
for ii in range(1000):
    target_head = None
    
    while target_head == None:
        target_head, target_body = generate_rule(target_rule,facts)
        if target_head != None:
            with open('temp.lp','wb') as outfile:
                outfile.write('.\n'.join(output_rules) + '.\n')
                outfile.write(prettify(target_head) + ':-' + ','.join([prettify(body) for body in target_body]) + '.\n')
                outfile.write('#show player_controls/1.')
            solved = solve(['temp.lp'])
            is_good = True
            found = []
            for t in solved:
                for tt in solved[t]:
                    for ttt in tt:
                        if prettify(ttt) in positives:
                            found.append(prettify(ttt))
                        else:
                            is_good = False
                            break
                    if not is_good:
                        break
                if not is_good:
                    break
            if is_good and len(found) == len(positives):
                print prettify(target_head) + ':-' + ','.join([prettify(body) for body in target_body]) + '.\n'
#rules_ = solve(['temp.lp'])
# Out:
# player_controls(Ventity0):-precondition(control_event(player_input(Vkey0,Vpress_type0)),Voutcome1),result(Voutcome1,moves(Ventity0,Vdirection0,Vscalar0)).
#
# player_controls(Ventity0):-precondition(control_event(Vcontrol_event0),Voutcome0),result(Voutcome0,moves(Ventity0,Vdirection0,Vscalar0)).
#
# player_controls(Ventity0):-precondition(control_event(Vcontrol_event0),Voutcome1),result(Voutcome1,moves(Ventity0,Vdirection0,Vscalar0)).
#
# player_controls(Ventity0):-result(Voutcome0,moves(Ventity0,Vdirection0,Vscalar0)),precondition(control_event(player_input(Vkey0,Vpress_type0)),Voutcome0).
#
# player_controls(Ventity0):-precondition(control_event(player_input(Vkey0,Vpress_type0)),Voutcome0),result(Voutcome0,moves(Ventity0,Vdirection0,Vscalar0)).
#
# player_controls(Ventity0):-result(Voutcome0,moves(Ventity0,Vdirection0,Vscalar0)),precondition(control_event(player_input(Vkey0,Vpress_type0)),Voutcome0).
#
# player_controls(Ventity0):-precondition(control_event(player_input(Vkey0,Vpress_type0)),Voutcome1),result(Voutcome1,moves(Ventity0,Vdirection0,Vscalar0)).
#
# player_controls(Ventity0):-precondition(control_event(player_input(Vkey0,Vpress_type0)),Voutcome1),result(Voutcome1,moves(Ventity0,Vdirection0,Vscalar0)).
